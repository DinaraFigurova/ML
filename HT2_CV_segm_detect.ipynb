# %% [markdown]
# # The Nature Conservancy Fisheries Monitoring

# %% [markdown]
# https://www.kaggle.com/c/the-nature-conservancy-fisheries-monitoring

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# # Загружаем разметку

# %%
import os
import json
from glob import glob

TRAIN_PREFIX = '/content/drive/MyDrive/data/fish/train'

def load_annotations():
    boxes = dict()
    for path in glob('/content/drive/MyDrive/data/fish/boxes/*.json'):
        label = os.path.basename(path).split('_', 1)[0]
        with open(path) as src:
            for annotation in json.load(src):
                basename = os.path.basename(annotation['filename'])
                annotation['filename'] = os.path.join(
                    TRAIN_PREFIX, label.upper(), basename)
                for rect in annotation['annotations']:
                    rect['x'] += rect['width'] / 2
                    rect['y'] += rect['height'] / 2
                if os.path.isfile(annotation['filename']):
                    boxes.setdefault(label, []).append(annotation)
    return boxes

def draw_boxes(annotation, rectangles=None, image_size=None):
    
    def _draw(img, rectangles, scale_x, scale_y, color=(0, 255, 0)):
        for rect in rectangles:
            pt1 = (int((rect['x'] - rect['width'] / 2) * scale_x),
                   int((rect['y'] - rect['height'] / 2) * scale_y))
            pt2 = (int((rect['x'] + rect['width'] / 2) * scale_x),
                   int((rect['y'] + rect['height'] / 2) * scale_y))
            img = cv2.rectangle(img.copy(), pt1, pt2, 
                                color=color, thickness=4)
        return img
    
    scale_x, scale_y = 1., 1.
    
    img = cv2.imread(annotation['filename'], cv2.IMREAD_COLOR)[...,::-1]
    if image_size is not None:
        scale_x = 1. * image_size[0] / img.shape[1]
        scale_y = 1. * image_size[1] / img.shape[0]
        img = cv2.resize(img, image_size)
        
    img = _draw(img, annotation.get('annotations', []), scale_x, scale_y)
    
    if rectangles is not None:
        img = _draw(img, rectangles, 1., 1., (255, 0, 0))

    return img

# %% [markdown]
# ### Визуализируем разметку

# %%
boxes = load_annotations()  # загружаем разметку детекций

# %%
pd.DataFrame(
    [(k, len(v)) for k, v in boxes.items()],
    columns=['class', 'count'])
# Out:
#    class  count
# 0    bet    200
# 1    yft    734
# 2    dol    117
# 3    lag     67
# 4  shark    176

# %%
from matplotlib import pyplot as plt


annotation = boxes['lag'][0]
img = draw_boxes(annotation)

plt.figure(figsize=(6, 6), dpi=120)
plt.imshow(img)
plt.title('{} {}x{}'.format(
    annotation['filename'], img.shape[0], img.shape[1]));

# %% [markdown]
# ### Распределение размеров разметки

# %%
annotations = sum([box['annotations']
                   for box in sum(boxes.values(), [])], [])

widths = [rect['width'] for rect in annotations]
heights = [rect['height'] for rect in annotations]

plt.hist(widths)
plt.hist(heights);

# %% [markdown]
# # Экстрактор признаков

# %%
from tensorflow.keras.applications import vgg16

IMG_HEIGHT = 750
IMG_WIDTH = 1200

features = vgg16.VGG16(weights='imagenet',
                       include_top=False,
                       input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# дообучаем последние 5 слоев
for layer in features.layers[:-5]:
    layer.trainable = False
    
feature_tensor = features.layers[-1].output
print(feature_tensor.shape)
# Out:
# (None, 23, 37, 512)

# %% [markdown]
# # Сетка якорей (anchor grid)

# %%
FEATURE_SHAPE = (feature_tensor.shape[1],
                 feature_tensor.shape[2])

GRID_STEP_H = IMG_HEIGHT / FEATURE_SHAPE[0]
GRID_STEP_W = IMG_WIDTH / FEATURE_SHAPE[1]

ANCHOR_WIDTH = 150.
ANCHOR_HEIGHT = 150. 

# сетка якорей, размер определяется соотношением 
# размера входного изображения и размером тензора признаков
ANCHOR_CENTERS = np.mgrid[GRID_STEP_H/2:IMG_HEIGHT:GRID_STEP_H,
                          GRID_STEP_W/2:IMG_WIDTH:GRID_STEP_W]

# %%
def iou(rect, x_scale, y_scale, anchor_x, anchor_y,
        anchor_w=ANCHOR_WIDTH, anchor_h=ANCHOR_HEIGHT):
    
    rect_x1 = (rect['x'] - rect['width'] / 2) * x_scale
    rect_x2 = (rect['x'] + rect['width'] / 2) * x_scale
    
    rect_y1 = (rect['y'] - rect['height'] / 2) * y_scale
    rect_y2 = (rect['y'] + rect['height'] / 2) * y_scale
    
    anch_x1, anch_x2 = anchor_x - anchor_w / 2, anchor_x + anchor_w / 2
    anch_y1, anch_y2 = anchor_y - anchor_h / 2, anchor_y + anchor_h / 2
    
    dx = (min(rect_x2, anch_x2) - max(rect_x1, anch_x1))
    dy = (min(rect_y2, anch_y2) - max(rect_y1, anch_y1))
    
    intersection = dx * dy if (dx > 0 and dy > 0) else 0.
    
    anch_square = (anch_x2 - anch_x1) * (anch_y2 - anch_y1)
    rect_square = (rect_x2 - rect_x1) * (rect_y2 - rect_y1)
    union = anch_square + rect_square - intersection
    
    return intersection / union

def encode_anchors(annotation, img_shape, iou_thr=0.5):
    encoded = np.zeros(shape=(FEATURE_SHAPE[0],
                              FEATURE_SHAPE[1], 5), dtype=np.float32)
    x_scale = 1. * IMG_WIDTH / img_shape[1]
    y_scale = 1. * IMG_HEIGHT / img_shape[0]
    for rect in annotation['annotations']:
        scores = []
        for row in range(FEATURE_SHAPE[0]):
            for col in range(FEATURE_SHAPE[1]):
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                score = iou(rect, x_scale, y_scale, anchor_x, anchor_y)
                scores.append((score, anchor_x, anchor_y, row, col))
        
        scores = sorted(scores, reverse=True)
        if scores[0][0] < iou_thr:
            scores = [scores[0]]  # default anchor
        else:
            scores = [e for e in scores if e[0] > iou_thr]

        for score, anchor_x, anchor_y, row, col in scores:
            dx = (anchor_x - rect['x'] * x_scale) / ANCHOR_WIDTH
            dy = (anchor_y - rect['y'] * y_scale) / ANCHOR_HEIGHT
            dw = (ANCHOR_WIDTH - rect['width'] * x_scale) / ANCHOR_WIDTH
            dh = (ANCHOR_HEIGHT - rect['height'] * y_scale) / ANCHOR_HEIGHT
            encoded[row, col] = [1., dx, dy, dw, dh]
            
    return encoded

def _sigmoid(x):
    return 1. / (1. + np.exp(-x))

def decode_prediction(prediction, conf_thr=0.1):
    rectangles = []
    for row in range(FEATURE_SHAPE[0]):
        for col in range(FEATURE_SHAPE[1]):
            logit, dx, dy, dw, dh = prediction[row, col]
            conf = _sigmoid(logit)
            if conf > conf_thr:
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                rectangles.append({'x': anchor_x - dx * ANCHOR_WIDTH,
                                   'y': anchor_y - dy * ANCHOR_HEIGHT,
                                   'width': ANCHOR_WIDTH - dw * ANCHOR_WIDTH,
                                   'height': ANCHOR_HEIGHT - dh * ANCHOR_HEIGHT,
                                   'conf': conf})
    return rectangles

def non_max_suppression(rectangles, max_output_size, iou_threshold=0.5):
    if not rectangles:
        return rectangles
    
    boxes = [[r['y'],
              r['x'],
              r['y'] + r['height'],
              r['x'] + r['width']] for r in rectangles]
    scores = [r['conf'] for r in rectangles]
    indices = tf.image.non_max_suppression(np.array(boxes),
                                           np.array(scores),
                                           max_output_size,
                                           iou_threshold)
    
    return [rectangles[i] for i in indices]

# %% [markdown]
# ### Валидация энкодинга/декодинга якорей

# %%
annotation = boxes['lag'][0]

encoded = encode_anchors(annotation,
                         img_shape=(IMG_HEIGHT, IMG_WIDTH),
                         iou_thr=0.5)

decoded = decode_prediction(encoded, conf_thr=0.7)
decoded = sorted(decoded, key = lambda e: -e['conf'])

plt.figure(figsize=(6, 6), dpi=120)
plt.imshow(draw_boxes(annotation, decoded))
plt.title('{} {}x{}'.format(
    annotation['filename'], img.shape[0], img.shape[1]));

# %% [markdown]
# ## Функция потерь

# %%
K = tf.keras.backend

def confidence_loss(y_true, y_pred):
    conf_loss = K.binary_crossentropy(y_true[..., 0], 
                                      y_pred[..., 0],
                                      from_logits=True)
    return conf_loss

def smooth_l1(y_true, y_pred):
    abs_loss = K.abs(y_true[..., 1:] - y_pred[..., 1:])
    square_loss = 0.5 * K.square(y_true[..., 1:] - y_pred[..., 1:])
    mask = K.cast(K.greater(abs_loss, 1.), 'float32')
    total_loss = (abs_loss - 0.5) * mask + 0.5 * square_loss * (1. - mask)
    return K.sum(total_loss, axis=-1)

def total_loss(y_true, y_pred, neg_pos_ratio=3):
    batch_size = K.shape(y_true)[0]
    
    # TODO: добавьте функцию потерь для классификации детекции
    
    y_true = K.reshape(y_true, (batch_size, -1, 5))
    y_pred = K.reshape(y_pred, (batch_size, -1, 5))

    # confidence loss
    conf_loss = confidence_loss(y_true, y_pred)
    
    # smooth l1 loss
    loc_loss = smooth_l1(y_true, y_pred)
    
    # positive examples loss
    pos_conf_loss = K.sum(conf_loss * y_true[..., 0], axis=-1)
    pos_loc_loss = K.sum(loc_loss * y_true[..., 0], axis=-1)
    
    # negative examples loss
    anchors = K.shape(y_true)[1]
    num_pos = K.sum(y_true[..., 0], axis=-1)
    num_pos_avg = K.mean(num_pos)
    num_neg = K.min([neg_pos_ratio * (num_pos_avg) + 1., K.cast(anchors, 'float32')])
    
    # hard negative mining
    neg_conf_loss, _ = tf.nn.top_k(conf_loss * (1. - y_true[..., 0]),
                                   k=K.cast(num_neg, 'int32'))

    neg_conf_loss = K.sum(neg_conf_loss, axis=-1)
    
    # total conf loss
    total_conf_loss = (neg_conf_loss + pos_conf_loss) / (num_neg + num_pos + 1e-32)
    loc_loss = pos_loc_loss / (num_pos + 1e-32)
    
    return total_conf_loss + 0.5 * loc_loss

# %% [markdown]
# ## Загрузка данных

# %%
from random import shuffle

def load_img(path, target_size=(IMG_WIDTH, IMG_HEIGHT)):
    img = cv2.imread(path, cv2.IMREAD_COLOR)[...,::-1]
    img_shape = img.shape
    img_resized = cv2.resize(img, target_size)
    return img_shape, vgg16.preprocess_input(img_resized.astype(np.float32))

def data_generator(boxes, batch_size=32):
    boxes = sum(boxes.values(), [])
    while True:
        shuffle(boxes)
        for i in range(len(boxes)//batch_size):
            X, y = [], []
            for j in range(i*batch_size,(i+1)*batch_size):
                img_shape, img = load_img(boxes[j]['filename'])
                # TODO: добавьте one-hot encoding в разметку для классов
                y.append(encode_anchors(boxes[j], img_shape))
                X.append(img)
            yield np.array(X), np.array(y)

# %% [markdown]
# ## Добавляем выход детектора

# %%
output = tf.keras.layers.BatchNormalization()(feature_tensor)

# TODO: добавьте выходы для классификации детекции
output = tf.keras.layers.Conv2D(5,
                                kernel_size=(1, 1), 
                                activation='linear',
                                kernel_regularizer='l2')(output)

model = tf.keras.models.Model(inputs=features.inputs, outputs=output)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 750, 1200, 3)]    0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 750, 1200, 64)     1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 750, 1200, 64)     36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 375, 600, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 375, 600, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 375, 600, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 187, 300, 128)     0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 187, 300, 256)     295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 187, 300, 256)     590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 187, 300, 256)     590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 93, 150, 256)      0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 93, 150, 512)      1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 93, 150, 512)      2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 93, 150, 512)      2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 46, 75, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 46, 75, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 46, 75, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 46, 75, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 23, 37, 512)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 23, 37, 512)       2048
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 23, 37, 5)         2565
# =================================================================
# Total params: 14,719,301
# Trainable params: 7,083,013
# Non-trainable params: 7,636,288
# _________________________________________________________________

# %% [markdown]
# ## Обучение

# %%
adam = tf.keras.optimizers.Adam(lr=3e-4, decay=1e-6)
model.compile(optimizer=adam, 
              loss=total_loss,
              metrics=[confidence_loss])

# %%
batch_size = 5

gen = data_generator(boxes, batch_size=batch_size)
steps_per_epoch = sum(map(len, boxes.values()), 0) / batch_size

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'fishdetector.hdf5',
    monitor='loss',
    verbose=1,  
    save_best_only=True, 
    save_weights_only=False,
    mode='auto',
    save_freq=10)

model.fit(gen, 
          steps_per_epoch=steps_per_epoch,
          epochs=35,
          callbacks=[checkpoint])
# Out:
# Epoch 1/35
#  10/258 [>.............................] - ETA: 1:17 - loss: 4.9850 - confidence_loss: 0.9118
# Epoch 00001: loss improved from inf to 4.27632, saving model to fishdetector.hdf5
#  20/258 [=>............................] - ETA: 1:17 - loss: 4.3322 - confidence_loss: 0.8876
# Epoch 00001: loss improved from 4.27632 to 3.27461, saving model to fishdetector.hdf5
#  30/258 [==>...........................] - ETA: 1:15 - loss: 3.8638 - confidence_loss: 0.8599
# Epoch 00001: loss improved from 3.27461 to 2.68837, saving model to fishdetector.hdf5
#  40/258 [===>..........................] - ETA: 1:12 - loss: 3.5225 - confidence_loss: 0.8345
# Epoch 00001: loss improved from 2.68837 to 2.35692, saving model to fishdetector.hdf5
#  50/258 [====>.........................] - ETA: 1:09 - loss: 3.2600 - confidence_loss: 0.8122
# Epoch 00001: loss improved from 2.35692 to 2.10137, saving model to fishdetector.hdf5
#  60/258 [=====>........................] - ETA: 1:05 - loss: 3.0475 - confidence_loss: 0.7925
# Epoch 00001: loss improved from 2.10137 to 1.90292, saving model to fishdetector.hdf5
#  70/258 [=======>......................] - ETA: 1:02 - loss: 2.8729 - confidence_loss: 0.7750
# Epoch 00001: loss improved from 1.90292 to 1.77092, saving model to fishdetector.hdf5
#  80/258 [========>.....................] - ETA: 59s - loss: 2.7273 - confidence_loss: 0.7593
# Epoch 00001: loss improved from 1.77092 to 1.66275, saving model to fishdetector.hdf5
#  90/258 [=========>....................] - ETA: 56s - loss: 2.6035 - confidence_loss: 0.7451
# Epoch 00001: loss improved from 1.66275 to 1.57487, saving model to fishdetector.hdf5
# 100/258 [==========>...................] - ETA: 53s - loss: 2.4963 - confidence_loss: 0.7321
# Epoch 00001: loss improved from 1.57487 to 1.50108, saving model to fishdetector.hdf5
# 110/258 [===========>..................] - ETA: 50s - loss: 2.4025 - confidence_loss: 0.7201
# Epoch 00001: loss improved from 1.50108 to 1.43554, saving model to fishdetector.hdf5
# 120/258 [============>.................] - ETA: 46s - loss: 2.3197 - confidence_loss: 0.7090
# Epoch 00001: loss improved from 1.43554 to 1.38676, saving model to fishdetector.hdf5
# 130/258 [==============>...............] - ETA: 43s - loss: 2.2459 - confidence_loss: 0.6986
# Epoch 00001: loss improved from 1.38676 to 1.34222, saving model to fishdetector.hdf5
# 140/258 [===============>..............] - ETA: 40s - loss: 2.1798 - confidence_loss: 0.6889
# Epoch 00001: loss improved from 1.34222 to 1.30454, saving model to fishdetector.hdf5
# 150/258 [================>.............] - ETA: 37s - loss: 2.1200 - confidence_loss: 0.6797
# Epoch 00001: loss improved from 1.30454 to 1.26672, saving model to fishdetector.hdf5
# 160/258 [=================>............] - ETA: 33s - loss: 2.0657 - confidence_loss: 0.6711
# Epoch 00001: loss improved from 1.26672 to 1.23960, saving model to fishdetector.hdf5
# 170/258 [==================>...........] - ETA: 30s - loss: 2.0162 - confidence_loss: 0.6629
# Epoch 00001: loss improved from 1.23960 to 1.20996, saving model to fishdetector.hdf5
# 180/258 [===================>..........] - ETA: 26s - loss: 1.9706 - confidence_loss: 0.6551
# Epoch 00001: loss improved from 1.20996 to 1.18509, saving model to fishdetector.hdf5
# 190/258 [=====================>........] - ETA: 23s - loss: 1.9286 - confidence_loss: 0.6477
# Epoch 00001: loss improved from 1.18509 to 1.16335, saving model to fishdetector.hdf5
# 200/258 [======================>.......] - ETA: 20s - loss: 1.8898 - confidence_loss: 0.6406
# Epoch 00001: loss improved from 1.16335 to 1.14177, saving model to fishdetector.hdf5
# 210/258 [=======================>......] - ETA: 16s - loss: 1.8537 - confidence_loss: 0.6338
# Epoch 00001: loss improved from 1.14177 to 1.12052, saving model to fishdetector.hdf5
# 220/258 [========================>.....] - ETA: 13s - loss: 1.8198 - confidence_loss: 0.6272
# Epoch 00001: loss improved from 1.12052 to 1.10066, saving model to fishdetector.hdf5
# 230/258 [=========================>....] - ETA: 9s - loss: 1.7881 - confidence_loss: 0.6210
# Epoch 00001: loss improved from 1.10066 to 1.08169, saving model to fishdetector.hdf5
# 240/258 [==========================>...] - ETA: 6s - loss: 1.7583 - confidence_loss: 0.6149
# Epoch 00001: loss improved from 1.08169 to 1.06704, saving model to fishdetector.hdf5
# 250/258 [===========================>..] - ETA: 3s - loss: 1.7303 - confidence_loss: 0.6091
# Epoch 00001: loss improved from 1.06704 to 1.05162, saving model to fishdetector.hdf5
# 258/258 [==============================] - 90s 342ms/step - loss: 1.7039 - confidence_loss: 0.6035
# Epoch 2/35
#   1/258 [..............................] - ETA: 1:14 - loss: 0.9375 - confidence_loss: 0.3026
# Epoch 00002: loss improved from 1.05162 to 0.93751, saving model to fishdetector.hdf5
#  11/258 [>.............................] - ETA: 1:23 - loss: 0.7305 - confidence_loss: 0.3014
# Epoch 00002: loss improved from 0.93751 to 0.67382, saving model to fishdetector.hdf5
#  21/258 [=>............................] - ETA: 1:20 - loss: 0.7000 - confidence_loss: 0.3000
# Epoch 00002: loss improved from 0.67382 to 0.65974, saving model to fishdetector.hdf5
#  31/258 [==>...........................] - ETA: 1:17 - loss: 0.6866 - confidence_loss: 0.2986
# Epoch 00002: loss improved from 0.65974 to 0.65473, saving model to fishdetector.hdf5
#  41/258 [===>..........................] - ETA: 1:14 - loss: 0.6795 - confidence_loss: 0.2973
# Epoch 00002: loss did not improve from 0.65473
#  51/258 [====>.........................] - ETA: 1:09 - loss: 0.6757 - confidence_loss: 0.2961
# Epoch 00002: loss did not improve from 0.65473
#  61/258 [======>.......................] - ETA: 1:05 - loss: 0.6742 - confidence_loss: 0.2950
# Epoch 00002: loss did not improve from 0.65473
#  71/258 [=======>......................] - ETA: 1:01 - loss: 0.6729 - confidence_loss: 0.2939
# Epoch 00002: loss did not improve from 0.65473
#  81/258 [========>.....................] - ETA: 57s - loss: 0.6721 - confidence_loss: 0.2928
# Epoch 00002: loss did not improve from 0.65473
#  91/258 [=========>....................] - ETA: 54s - loss: 0.6713 - confidence_loss: 0.2917
# Epoch 00002: loss did not improve from 0.65473
# 101/258 [==========>...................] - ETA: 51s - loss: 0.6707 - confidence_loss: 0.2906
# Epoch 00002: loss did not improve from 0.65473
# 111/258 [===========>..................] - ETA: 47s - loss: 0.6700 - confidence_loss: 0.2895
# Epoch 00002: loss did not improve from 0.65473
# 121/258 [=============>................] - ETA: 44s - loss: 0.6691 - confidence_loss: 0.2884
# Epoch 00002: loss did not improve from 0.65473
# 131/258 [==============>...............] - ETA: 40s - loss: 0.6683 - confidence_loss: 0.2873
# Epoch 00002: loss did not improve from 0.65473
# 141/258 [===============>..............] - ETA: 37s - loss: 0.6674 - confidence_loss: 0.2863
# Epoch 00002: loss did not improve from 0.65473
# 151/258 [================>.............] - ETA: 34s - loss: 0.6665 - confidence_loss: 0.2852
# Epoch 00002: loss improved from 0.65473 to 0.65229, saving model to fishdetector.hdf5
# 161/258 [=================>............] - ETA: 31s - loss: 0.6655 - confidence_loss: 0.2842
# Epoch 00002: loss improved from 0.65229 to 0.65033, saving model to fishdetector.hdf5
# 171/258 [==================>...........] - ETA: 28s - loss: 0.6645 - confidence_loss: 0.2831
# Epoch 00002: loss improved from 0.65033 to 0.64922, saving model to fishdetector.hdf5
# 181/258 [===================>..........] - ETA: 25s - loss: 0.6636 - confidence_loss: 0.2821
# Epoch 00002: loss improved from 0.64922 to 0.64710, saving model to fishdetector.hdf5
# 191/258 [=====================>........] - ETA: 21s - loss: 0.6627 - confidence_loss: 0.2811
# Epoch 00002: loss improved from 0.64710 to 0.64691, saving model to fishdetector.hdf5
# 201/258 [======================>.......] - ETA: 18s - loss: 0.6619 - confidence_loss: 0.2801
# Epoch 00002: loss improved from 0.64691 to 0.64577, saving model to fishdetector.hdf5
# 211/258 [=======================>......] - ETA: 15s - loss: 0.6611 - confidence_loss: 0.2791
# Epoch 00002: loss improved from 0.64577 to 0.64479, saving model to fishdetector.hdf5
# 221/258 [========================>.....] - ETA: 12s - loss: 0.6603 - confidence_loss: 0.2781
# Epoch 00002: loss did not improve from 0.64479
# 231/258 [=========================>....] - ETA: 9s - loss: 0.6597 - confidence_loss: 0.2771
# Epoch 00002: loss improved from 0.64479 to 0.64440, saving model to fishdetector.hdf5
# 241/258 [==========================>...] - ETA: 5s - loss: 0.6590 - confidence_loss: 0.2761
# Epoch 00002: loss improved from 0.64440 to 0.64350, saving model to fishdetector.hdf5
# 251/258 [============================>.] - ETA: 2s - loss: 0.6584 - confidence_loss: 0.2752
# Epoch 00002: loss did not improve from 0.64350
# 258/258 [==============================] - 85s 327ms/step - loss: 0.6578 - confidence_loss: 0.2743
# Epoch 3/35
#   2/258 [..............................] - ETA: 1:20 - loss: 0.5680 - confidence_loss: 0.2120
# Epoch 00003: loss improved from 0.64350 to 0.58486, saving model to fishdetector.hdf5
#  12/258 [>.............................] - ETA: 1:22 - loss: 0.5931 - confidence_loss: 0.2103
# Epoch 00003: loss did not improve from 0.58486
#  22/258 [=>............................] - ETA: 1:17 - loss: 0.5978 - confidence_loss: 0.2094
# Epoch 00003: loss did not improve from 0.58486
#  32/258 [==>...........................] - ETA: 1:13 - loss: 0.6019 - confidence_loss: 0.2087
# Epoch 00003: loss did not improve from 0.58486
#  42/258 [===>..........................] - ETA: 1:09 - loss: 0.6062 - confidence_loss: 0.2081
# Epoch 00003: loss did not improve from 0.58486
#  52/258 [=====>........................] - ETA: 1:06 - loss: 0.6088 - confidence_loss: 0.2076
# Epoch 00003: loss did not improve from 0.58486
#  62/258 [======>.......................] - ETA: 1:03 - loss: 0.6106 - confidence_loss: 0.2070
# Epoch 00003: loss did not improve from 0.58486
#  72/258 [=======>......................] - ETA: 1:00 - loss: 0.6119 - confidence_loss: 0.2065
# Epoch 00003: loss did not improve from 0.58486
#  82/258 [========>.....................] - ETA: 56s - loss: 0.6129 - confidence_loss: 0.2061
# Epoch 00003: loss did not improve from 0.58486
#  92/258 [=========>....................] - ETA: 53s - loss: 0.6134 - confidence_loss: 0.2056
# Epoch 00003: loss did not improve from 0.58486
# Epoch 00005: loss did not improve from 0.52743
#  14/258 [>.............................] - ETA: 1:16 - loss: 0.5727 - confidence_loss: 0.1111
# Epoch 00005: loss did not improve from 0.52743
#  24/258 [=>............................] - ETA: 1:12 - loss: 0.5515 - confidence_loss: 0.1098
# Epoch 00005: loss improved from 0.52743 to 0.52019, saving model to fishdetector.hdf5
#  34/258 [==>...........................] - ETA: 1:12 - loss: 0.5431 - confidence_loss: 0.1091
# Epoch 00005: loss did not improve from 0.52019
#  44/258 [====>.........................] - ETA: 1:08 - loss: 0.5383 - confidence_loss: 0.1086
# Epoch 00005: loss improved from 0.52019 to 0.51629, saving model to fishdetector.hdf5
#  54/258 [=====>........................] - ETA: 1:05 - loss: 0.5340 - confidence_loss: 0.1081
# Epoch 00005: loss improved from 0.51629 to 0.51144, saving model to fishdetector.hdf5
#  64/258 [======>.......................] - ETA: 1:03 - loss: 0.5305 - confidence_loss: 0.1075
# Epoch 00005: loss did not improve from 0.51144
#  74/258 [=======>......................] - ETA: 59s - loss: 0.5282 - confidence_loss: 0.1070
# Epoch 00005: loss improved from 0.51144 to 0.51107, saving model to fishdetector.hdf5
#  84/258 [========>.....................] - ETA: 56s - loss: 0.5260 - confidence_loss: 0.1065
# Epoch 00005: loss improved from 0.51107 to 0.51069, saving model to fishdetector.hdf5
#  94/258 [=========>....................] - ETA: 53s - loss: 0.5243 - confidence_loss: 0.1060
# Epoch 00005: loss improved from 0.51069 to 0.50988, saving model to fishdetector.hdf5
# 104/258 [===========>..................] - ETA: 50s - loss: 0.5228 - confidence_loss: 0.1055
# Epoch 00005: loss improved from 0.50988 to 0.50872, saving model to fishdetector.hdf5
# 114/258 [============>.................] - ETA: 47s - loss: 0.5216 - confidence_loss: 0.1051
# Epoch 00005: loss improved from 0.50872 to 0.50776, saving model to fishdetector.hdf5
# 124/258 [=============>................] - ETA: 44s - loss: 0.5203 - confidence_loss: 0.1046
# Epoch 00005: loss improved from 0.50776 to 0.50435, saving model to fishdetector.hdf5
# 134/258 [==============>...............] - ETA: 40s - loss: 0.5193 - confidence_loss: 0.1042
# Epoch 00005: loss did not improve from 0.50435
# 144/258 [===============>..............] - ETA: 37s - loss: 0.5182 - confidence_loss: 0.1038
# Epoch 00005: loss improved from 0.50435 to 0.50277, saving model to fishdetector.hdf5
# 154/258 [================>.............] - ETA: 34s - loss: 0.5171 - confidence_loss: 0.1034
# Epoch 00005: loss improved from 0.50277 to 0.49881, saving model to fishdetector.hdf5
# 164/258 [==================>...........] - ETA: 31s - loss: 0.5159 - confidence_loss: 0.1031
# Epoch 00005: loss improved from 0.49881 to 0.49599, saving model to fishdetector.hdf5
# 174/258 [===================>..........] - ETA: 27s - loss: 0.5147 - confidence_loss: 0.1027
# Epoch 00005: loss improved from 0.49599 to 0.49444, saving model to fishdetector.hdf5
# 184/258 [====================>.........] - ETA: 24s - loss: 0.5136 - confidence_loss: 0.1023
# Epoch 00005: loss improved from 0.49444 to 0.49317, saving model to fishdetector.hdf5
# 194/258 [=====================>........] - ETA: 21s - loss: 0.5125 - confidence_loss: 0.1019
# Epoch 00012: loss did not improve from 0.16860
# 131/258 [==============>...............] - ETA: 40s - loss: 0.1976 - confidence_loss: 0.0092
# Epoch 00012: loss did not improve from 0.16860
# 141/258 [===============>..............] - ETA: 37s - loss: 0.1972 - confidence_loss: 0.0092
# Epoch 00012: loss did not improve from 0.16860
# 151/258 [================>.............] - ETA: 34s - loss: 0.1967 - confidence_loss: 0.0091
# Epoch 00012: loss did not improve from 0.16860
# 161/258 [=================>............] - ETA: 31s - loss: 0.1964 - confidence_loss: 0.0091
# Epoch 00012: loss did not improve from 0.16860
# 171/258 [==================>...........] - ETA: 27s - loss: 0.1961 - confidence_loss: 0.0091
# Epoch 00012: loss did not improve from 0.16860
# 181/258 [===================>..........] - ETA: 24s - loss: 0.1958 - confidence_loss: 0.0091
# Epoch 00012: loss did not improve from 0.16860
# 191/258 [=====================>........] - ETA: 21s - loss: 0.1956 - confidence_loss: 0.0091
# Epoch 00012: loss did not improve from 0.16860
# 201/258 [======================>.......] - ETA: 18s - loss: 0.1956 - confidence_loss: 0.0091
# Epoch 00012: loss did not improve from 0.16860
# 211/258 [=======================>......] - ETA: 15s - loss: 0.1956 - confidence_loss: 0.0091
# Epoch 00012: loss did not improve from 0.16860
# 221/258 [========================>.....] - ETA: 11s - loss: 0.1958 - confidence_loss: 0.0090
# Epoch 00012: loss did not improve from 0.16860
# 231/258 [=========================>....] - ETA: 8s - loss: 0.1961 - confidence_loss: 0.0090
# Epoch 00012: loss did not improve from 0.16860
# 241/258 [==========================>...] - ETA: 5s - loss: 0.1964 - confidence_loss: 0.0090
# Epoch 00012: loss did not improve from 0.16860
# 251/258 [============================>.] - ETA: 2s - loss: 0.1967 - confidence_loss: 0.0090
# Epoch 00012: loss did not improve from 0.16860
# 258/258 [==============================] - 82s 317ms/step - loss: 0.1969 - confidence_loss: 0.0090
# Epoch 13/35
#   2/258 [..............................] - ETA: 1:21 - loss: 0.1843 - confidence_loss: 0.0073
# Epoch 00013: loss did not improve from 0.16860
# ...
# 200/258 [======================>.......] - ETA: 18s - loss: 0.0486 - confidence_loss: 0.0025
# Epoch 00031: loss did not improve from 0.03541
# 210/258 [=======================>......] - ETA: 15s - loss: 0.0488 - confidence_loss: 0.0026
# Epoch 00031: loss did not improve from 0.03541
# 220/258 [========================>.....] - ETA: 12s - loss: 0.0490 - confidence_loss: 0.0026
# Epoch 00031: loss did not improve from 0.03541
# 230/258 [=========================>....] - ETA: 9s - loss: 0.0493 - confidence_loss: 0.0026
# Epoch 00031: loss did not improve from 0.03541
# 240/258 [==========================>...] - ETA: 5s - loss: 0.0495 - confidence_loss: 0.0026
# Epoch 00031: loss did not improve from 0.03541
# 250/258 [===========================>..] - ETA: 2s - loss: 0.0497 - confidence_loss: 0.0026
# Epoch 00031: loss did not improve from 0.03541
# 258/258 [==============================] - 83s 319ms/step - loss: 0.0499 - confidence_loss: 0.0026
# Epoch 32/35
#   1/258 [..............................] - ETA: 1:24 - loss: 0.0473 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
#  11/258 [>.............................] - ETA: 1:19 - loss: 0.0562 - confidence_loss: 0.0026
# Epoch 00032: loss did not improve from 0.03541
#  21/258 [=>............................] - ETA: 1:15 - loss: 0.0510 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
#  31/258 [==>...........................] - ETA: 1:12 - loss: 0.0478 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
#  41/258 [===>..........................] - ETA: 1:09 - loss: 0.0459 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
#  51/258 [====>.........................] - ETA: 1:06 - loss: 0.0444 - confidence_loss: 0.0024
# Epoch 00032: loss did not improve from 0.03541
#  61/258 [======>.......................] - ETA: 1:02 - loss: 0.0446 - confidence_loss: 0.0024
# Epoch 00032: loss did not improve from 0.03541
#  71/258 [=======>......................] - ETA: 59s - loss: 0.0451 - confidence_loss: 0.0024
# Epoch 00032: loss did not improve from 0.03541
#  81/258 [========>.....................] - ETA: 56s - loss: 0.0455 - confidence_loss: 0.0024
# Epoch 00032: loss did not improve from 0.03541
#  91/258 [=========>....................] - ETA: 53s - loss: 0.0459 - confidence_loss: 0.0024
# Epoch 00032: loss did not improve from 0.03541
# 101/258 [==========>...................] - ETA: 50s - loss: 0.0461 - confidence_loss: 0.0024
# Epoch 00032: loss did not improve from 0.03541
# 111/258 [===========>..................] - ETA: 47s - loss: 0.0464 - confidence_loss: 0.0024
# Epoch 00032: loss did not improve from 0.03541
# 121/258 [=============>................] - ETA: 43s - loss: 0.0466 - confidence_loss: 0.0024
# Epoch 00032: loss did not improve from 0.03541
# 131/258 [==============>...............] - ETA: 40s - loss: 0.0468 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
# 141/258 [===============>..............] - ETA: 37s - loss: 0.0472 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
# 151/258 [================>.............] - ETA: 34s - loss: 0.0476 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
# 161/258 [=================>............] - ETA: 31s - loss: 0.0480 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
# 171/258 [==================>...........] - ETA: 28s - loss: 0.0484 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
# 181/258 [===================>..........] - ETA: 24s - loss: 0.0488 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
# 191/258 [=====================>........] - ETA: 21s - loss: 0.0491 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
# 201/258 [======================>.......] - ETA: 18s - loss: 0.0494 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
# 211/258 [=======================>......] - ETA: 15s - loss: 0.0496 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
# 221/258 [========================>.....] - ETA: 12s - loss: 0.0498 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
# 231/258 [=========================>....] - ETA: 8s - loss: 0.0500 - confidence_loss: 0.0025
# Epoch 00032: loss did not improve from 0.03541
# Epoch 00034: loss did not improve from 0.02712
# 173/258 [===================>..........] - ETA: 27s - loss: 0.0647 - confidence_loss: 0.0028
# Epoch 00034: loss did not improve from 0.02712
# 183/258 [====================>.........] - ETA: 24s - loss: 0.0645 - confidence_loss: 0.0028
# Epoch 00034: loss did not improve from 0.02712
# 193/258 [=====================>........] - ETA: 20s - loss: 0.0644 - confidence_loss: 0.0028
# Epoch 00034: loss did not improve from 0.02712
# 203/258 [======================>.......] - ETA: 17s - loss: 0.0644 - confidence_loss: 0.0028
# Epoch 00034: loss did not improve from 0.02712
# 213/258 [=======================>......] - ETA: 14s - loss: 0.0644 - confidence_loss: 0.0028
# Epoch 00034: loss did not improve from 0.02712
# 223/258 [========================>.....] - ETA: 11s - loss: 0.0644 - confidence_loss: 0.0028
# Epoch 00034: loss did not improve from 0.02712
# 233/258 [==========================>...] - ETA: 8s - loss: 0.0644 - confidence_loss: 0.0028
# Epoch 00034: loss did not improve from 0.02712
# 243/258 [===========================>..] - ETA: 5s - loss: 0.0645 - confidence_loss: 0.0028
# Epoch 00034: loss did not improve from 0.02712
# 253/258 [============================>.] - ETA: 1s - loss: 0.0645 - confidence_loss: 0.0027
# Epoch 00034: loss did not improve from 0.02712
# 258/258 [==============================] - 83s 319ms/step - loss: 0.0646 - confidence_loss: 0.0027
# Epoch 35/35
#   4/258 [..............................] - ETA: 1:20 - loss: 0.0825 - confidence_loss: 0.0033
# Epoch 00035: loss did not improve from 0.02712
#  14/258 [>.............................] - ETA: 1:16 - loss: 0.0769 - confidence_loss: 0.0032
# Epoch 00035: loss did not improve from 0.02712
#  24/258 [=>............................] - ETA: 1:14 - loss: 0.0737 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
#  34/258 [==>...........................] - ETA: 1:11 - loss: 0.0749 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
#  44/258 [====>.........................] - ETA: 1:08 - loss: 0.0752 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
#  54/258 [=====>........................] - ETA: 1:05 - loss: 0.0766 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
#  64/258 [======>.......................] - ETA: 1:02 - loss: 0.0778 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
#  74/258 [=======>......................] - ETA: 58s - loss: 0.0783 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
#  84/258 [========>.....................] - ETA: 55s - loss: 0.0784 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
#  94/258 [=========>....................] - ETA: 52s - loss: 0.0782 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 104/258 [===========>..................] - ETA: 49s - loss: 0.0780 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 114/258 [============>.................] - ETA: 46s - loss: 0.0777 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 124/258 [=============>................] - ETA: 42s - loss: 0.0775 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 134/258 [==============>...............] - ETA: 39s - loss: 0.0772 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 144/258 [===============>..............] - ETA: 36s - loss: 0.0769 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 154/258 [================>.............] - ETA: 33s - loss: 0.0767 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 164/258 [==================>...........] - ETA: 30s - loss: 0.0765 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 174/258 [===================>..........] - ETA: 27s - loss: 0.0763 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 184/258 [====================>.........] - ETA: 23s - loss: 0.0761 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 194/258 [=====================>........] - ETA: 20s - loss: 0.0761 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 204/258 [======================>.......] - ETA: 17s - loss: 0.0761 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 214/258 [=======================>......] - ETA: 14s - loss: 0.0761 - confidence_loss: 0.0031
# Epoch 00035: loss did not improve from 0.02712
# 224/258 [========================>.....] - ETA: 11s - loss: 0.0761 - confidence_loss: 0.0030
# Epoch 00035: loss did not improve from 0.02712
# 234/258 [==========================>...] - ETA: 7s - loss: 0.0761 - confidence_loss: 0.0030
# Epoch 00035: loss did not improve from 0.02712
# 244/258 [===========================>..] - ETA: 4s - loss: 0.0760 - confidence_loss: 0.0030
# Epoch 00035: loss did not improve from 0.02712
# 254/258 [============================>.] - ETA: 1s - loss: 0.0759 - confidence_loss: 0.0030
# Epoch 00035: loss did not improve from 0.02712
# 258/258 [==============================] - 83s 320ms/step - loss: 0.0759 - confidence_loss: 0.0030

# %% [markdown]
# ## Результат работы детектора

# %%
# model.load_weights('/content/drive/MyDrive/data/fish/fishdetector_weights.hdf5')

# %%
annotation = boxes['lag'][0]

_, sample_img = load_img(annotation['filename'])
pred = model.predict(np.array([sample_img,]))

decoded = decode_prediction(pred[0], conf_thr=0.2)
decoded = non_max_suppression(decoded,
                              max_output_size=5,
                              iou_threshold=0.1)

plt.figure(figsize=(6, 6), dpi=120)
img = draw_boxes(annotation, decoded, (IMG_WIDTH, IMG_HEIGHT))
plt.imshow(img)
plt.title('Предсказание модели {}x{}'.format(*img.shape));

# %% [markdown]
# ## Визуализируем предсказание на тесте

# %%
test_images = glob('/content/drive/MyDrive/data/fish/test_stg1/*.jpg')[:5]


plt.figure(figsize=(6, 4 * len(test_images)), dpi=120)

for i, filename in enumerate(test_images):
    _, sample_img = load_img(filename)
    pred = model.predict(np.array([sample_img,]))

    decoded = decode_prediction(pred[0], conf_thr=0.0)
    decoded = non_max_suppression(decoded,
                                  max_output_size=2,
                                  iou_threshold=0.1)
    
    plt.subplot(len(test_images), 1, i + 1)
    img = draw_boxes({'filename': filename}, decoded, (IMG_WIDTH, IMG_HEIGHT))
    plt.imshow(img)
    plt.title('Предсказание на тесте {}'.format(filename));
